# %% [markdown]
#                           Working with Real Project with Python
#
# Here, The weather dataset is a time series data set with per-hour information about the weather conditions location. It records temperature, Dew Point Temprature, Relative Humidity, Wind Speed, Visibility, Pressure, and Conditions.

# %%
import pandas as pd

# %%
df= pd.read_csv('Weather.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Humidity_%    8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# Q1. Finding the all unique 'Wind Speed' values in the data:

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# Answer1

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# Q2. Finding the number of times when the 'weather is exactly clear':

# %%
# Three ways to solve this problem by; 
# 1. .value_counts()
# 2. filtering
# 3. groupby()

df['Weather'].value_counts()

# We can see the result: There is 1326 results are with clear weather.
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# Filtering
df[df.Weather == 'Clear']

# We can see the all 1326 records with clear weather only.
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# Groupby()
df.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  \
# 67      1/3/2012 19:00   -16.9             -24.8              50
# 114     1/5/2012 18:00    -7.1             -14.4              56
# 115     1/5/2012 19:00    -9.2             -15.4              61
# 116     1/5/2012 20:00    -9.8             -15.7              62
# 117     1/5/2012 21:00    -9.0             -14.8              63
# ...                ...     ...               ...             ...
# 8646   12/26/2012 6:00   -13.4             -14.8              89
# 8698  12/28/2012 10:00    -6.1              -8.6              82
# 8713   12/29/2012 1:00   -11.9             -13.6              87
# 8714   12/29/2012 2:00   -11.8             -13.1              90
# 8756  12/30/2012 20:00   -13.8             -16.5              80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %% [markdown]
# Q3. Finding the number of times when the 'Wind Speed was exactly 4km/h.

# %%
df[df['Wind Speed_km/h']== 4].head()

# We can see the 474 rows in the data set with the wind speed 4km/h.
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9              86                4
# 1    1/1/2012 1:00    -1.8              -3.7              87                4
# 96   1/5/2012 0:00    -8.8             -11.7              79                4
# 101  1/5/2012 5:00    -7.0              -9.5              82                4
# 146  1/7/2012 2:00    -8.1             -11.1              79                4
#
#      Visibility_km  Press_kPa Weather
# 0              8.0     101.24     Fog
# 1              8.0     101.24     Fog
# 96             9.7     100.32    Snow
# 101            4.0     100.19    Snow
# 146           19.3     100.15  Cloudy

# %% [markdown]
# Q4. Finding out all the null values in the data.

# %%
# df.isnull() # For boolean value
df.isnull().sum() # This line of code will shows null values in form of columns.

#  We can also use .notnull() function by following bewlow line of code
# df.notnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# Q5. Rename the column name 'Rel Hum_%' of the dataframe to 'Rel Humidity_%'.

# %%
df.rename(columns= {'Rel Hum_%':'Rel Humidity_%'}).head() # This is for temprary purpose.

# df.rename(columns= {'Rel Hum_%':'Rel Humidity_%'}, inplace =True) # This is for parmanant rename 


# Now we can see the result
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9              86                4
# 1  1/1/2012 1:00    -1.8              -3.7              87                4
# 2  1/1/2012 2:00    -1.8              -3.4              89                7
# 3  1/1/2012 3:00    -1.5              -3.2              88                6
# 4  1/1/2012 4:00    -1.5              -3.3              88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# Q6. What is the mean valuse of visibility column?

# %%
df.Visibility_km.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# Q7. What is the standard deviation of 'Pressure' in data?

# %%
df.Press_kPa.std()
# Out:
# 0.8440047459486483

# %% [markdown]
# Q8. What is the Variance of 'Relative Humidity' in this data?

# %%
df['Rel Humidity_%'].var()
# Out:
# 286.24855019850196

# %% [markdown]
# Q9. Finding all intances when 'Snow, Fog' was recorded

# %%
df[df.Weather == 'Snow'].head()

#  There are 390 records.
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  Wind Speed_km/h  \
# 55   1/3/2012 7:00   -14.0             -19.5              63               19
# 84  1/4/2012 12:00   -13.7             -21.7              51               11
# 86  1/4/2012 14:00   -11.3             -19.0              53                7
# 87  1/4/2012 15:00   -10.2             -16.3              61               11
# 88  1/4/2012 16:00    -9.4             -15.5              61               13
#
#     Visibility_km  Press_kPa Weather
# 55           25.0     100.95    Snow
# 84           24.1     101.25    Snow
# 86           19.3     100.97    Snow
# 87            9.7     100.89    Snow
# 88           19.3     100.79    Snow

# %%
df[df['Weather'].str.contains('Snow')].head(25)

# We can see all the records that contains 'Snow' word. 
# And such as 583 records are there.
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  Wind Speed_km/h  \
# 41  1/2/2012 17:00    -2.1              -9.5              57               22
# 44  1/2/2012 20:00    -5.6             -13.4              54               24
# 45  1/2/2012 21:00    -5.8             -12.8              58               26
# 47  1/2/2012 23:00    -7.4             -14.1              59               17
# 48   1/3/2012 0:00    -9.0             -16.0              57               28
# 50   1/3/2012 2:00   -10.5             -15.8              65               22
# 51   1/3/2012 3:00   -11.3             -18.7              54               33
# 53   1/3/2012 5:00   -12.9             -19.1              60               22
# 54   1/3/2012 6:00   -13.3             -19.3              61               19
# 55   1/3/2012 7:00   -14.0             -19.5              63               19
# 84  1/4/2012 12:00   -13.7             -21.7              51               11
# ...

# %% [markdown]
# Q10. Finding all instances when 'Wind Speed is 28' and 'Visibility is 25':

# %%
df[(df['Wind Speed_km/h'] > 28) & (df['Visibility_km']==25)].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  Wind Speed_km/h  \
# 23  1/1/2012 23:00     5.3               2.0              79               30
# 24   1/2/2012 0:00     5.2               1.5              77               35
# 25   1/2/2012 1:00     4.6               0.0              72               39
# 26   1/2/2012 2:00     3.9              -0.9              71               32
# 27   1/2/2012 3:00     3.7              -1.5              69               33
#
#     Visibility_km  Press_kPa        Weather
# 23           25.0      99.31         Cloudy
# 24           25.0      99.26   Rain Showers
# 25           25.0      99.26         Cloudy
# 26           25.0      99.26  Mostly Cloudy
# 27           25.0      99.30  Mostly Cloudy

# %% [markdown]
# Q11. What is the mean value of each column against each 'Weather'?

# %%
df.groupby('Weather').mean().head()
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_21348\1226088186.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Weather').mean().head()
#                            Temp_C  Dew Point Temp_C  Rel Humidity_%  \
# Weather
# Clear                    6.825716          0.089367       64.497738
# Cloudy                   7.970544          2.375810       69.592593
# Drizzle                  7.353659          5.504878       88.243902
# Drizzle,Fog              8.067500          7.033750       93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000       92.000000
#
#                          Wind Speed_km/h  Visibility_km   Press_kPa
# Weather
# Clear                          10.557315      30.153243  101.587443
# ...

# %% [markdown]
# Q12. What is the Minimum & Maximum values of each coclumn against 'Weather' columns?

# %%
df.groupby('Weather').min().head()
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  \
# Weather
# Clear                     1/11/2012 1:00   -23.3             -28.5
# Cloudy                    1/1/2012 17:00   -21.4             -26.8
# Drizzle                  1/23/2012 21:00     1.1              -0.2
# Drizzle,Fog              1/23/2012 20:00     0.0              -1.6
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7
#
#                          Rel Humidity_%  Wind Speed_km/h  Visibility_km  \
# Weather
# Clear                                20                0           11.3
# Cloudy                               18                0           11.3
# Drizzle                              74                0            6.4
# Drizzle,Fog                          85                0            1.0
# Drizzle,Ice Pellets,Fog              92               20            4.0
#
#                          Press_kPa
# Weather
# Clear                        99.52
# ...

# %%
df.groupby('Weather').max().head()
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  \
# Weather
# Clear                      9/9/2012 5:00    32.8              20.4
# Cloudy                    9/9/2012 23:00    30.5              22.6
# Drizzle                   9/30/2012 3:00    18.8              17.7
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7
#
#                          Rel Humidity_%  Wind Speed_km/h  Visibility_km  \
# Weather
# Clear                                99               33           48.3
# Cloudy                               99               54           48.3
# Drizzle                              96               30           25.0
# Drizzle,Fog                         100               28            9.7
# Drizzle,Ice Pellets,Fog              92               20            4.0
#
#                          Press_kPa
# Weather
# Clear                       103.63
# ...

# %% [markdown]
# Q13. Finding all records where 'Weather' is 'Fog':

# %%
# df[df.Weather == 'Rain']
df.groupby('Weather').get_group('Rain')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  \
# 18      1/1/2012 18:00     3.8               1.0              82
# 19      1/1/2012 19:00     3.1               1.3              88
# 542    1/23/2012 14:00     2.7              -1.1              76
# 543    1/23/2012 15:00     2.7              -0.9              77
# 545    1/23/2012 17:00     3.1              -0.4              78
# ...                ...     ...               ...             ...
# 8537  12/21/2012 17:00     1.3               0.2              92
# 8538  12/21/2012 18:00     1.4               0.3              92
# 8539  12/21/2012 19:00     2.3               1.1              92
# 8540  12/21/2012 20:00     2.4               1.7              95
# 8541  12/21/2012 21:00     1.3               0.4              94
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 18                 15           12.9      99.74    Rain
# 19                 15           12.9      99.68    Rain
# ...

# %%
df[df['Weather'].str.contains('Fog')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  \
# 0        1/1/2012 0:00    -1.8              -3.9              86
# 1        1/1/2012 1:00    -1.8              -3.7              87
# 2        1/1/2012 2:00    -1.8              -3.4              89
# 3        1/1/2012 3:00    -1.5              -3.2              88
# 4        1/1/2012 4:00    -1.5              -3.3              88
# ...                ...     ...               ...             ...
# 8739   12/30/2012 3:00    -9.1             -10.4              90
# 8740   12/30/2012 4:00    -9.3             -10.6              90
# 8741   12/30/2012 5:00    -9.1             -10.4              90
# 8742   12/30/2012 6:00    -9.3             -10.8              89
# 8770  12/31/2012 10:00    -7.4              -8.9              89
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# Q14. Finding all instances when 'Weather is Clear' or 'Visibility is above 35':

# %%
df[(df['Weather']== 'Clear') | (df['Visibility_km']>35)]

# There are 3027 records.
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  \
# 67      1/3/2012 19:00   -16.9             -24.8              50
# 106     1/5/2012 10:00    -6.0             -10.0              73
# 107     1/5/2012 11:00    -5.6             -10.2              70
# 108     1/5/2012 12:00    -4.7              -9.6              69
# 109     1/5/2012 13:00    -4.4              -9.7              66
# ...                ...     ...               ...             ...
# 8749  12/30/2012 13:00   -12.4             -16.2              73
# 8750  12/30/2012 14:00   -11.8             -16.1              70
# 8751  12/30/2012 15:00   -11.3             -15.6              70
# 8752  12/30/2012 16:00   -11.4             -15.5              72
# 8756  12/30/2012 20:00   -13.8             -16.5              80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa        Weather
# 67                 24           25.0     101.74          Clear
# ...

# %% [markdown]
# Q15. Finding all intances when:
#
# A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
#               or
# B. 'Visibility is above 40'

# %%
df[(df['Weather']== 'Clear') & (df['Rel Humidity_%']>50) | (df['Visibility_km']>40)]

# There are 2921 records with these parameters.
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Humidity_%  \
# 106     1/5/2012 10:00    -6.0             -10.0              73
# 107     1/5/2012 11:00    -5.6             -10.2              70
# 108     1/5/2012 12:00    -4.7              -9.6              69
# 109     1/5/2012 13:00    -4.4              -9.7              66
# 110     1/5/2012 14:00    -5.1             -10.7              65
# ...                ...     ...               ...             ...
# 8749  12/30/2012 13:00   -12.4             -16.2              73
# 8750  12/30/2012 14:00   -11.8             -16.1              70
# 8751  12/30/2012 15:00   -11.3             -15.6              70
# 8752  12/30/2012 16:00   -11.4             -15.5              72
# 8756  12/30/2012 20:00   -13.8             -16.5              80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa        Weather
# 106                17           48.3     100.45   Mainly Clear
# ...
